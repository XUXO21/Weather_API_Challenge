# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santa cruz
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 1 | baturite
# Processing Record 5 of Set 1 | riihimaki
# Processing Record 6 of Set 1 | boda
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | dingle
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | faanui
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | kikwit
# Processing Record 18 of Set 1 | nago
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | tandur
# Processing Record 21 of Set 1 | inta
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | safwah
# City not found. Skipping...
# Processing Record 26 of Set 1 | glubokoe
# City not found. Skipping...
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | caravelas
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | tezu
# Processing Record 34 of Set 1 | wa
# City not found. Skipping...
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | richards bay
# Processing Record 43 of Set 1 | margasari
# Processing Record 44 of Set 1 | naryan-mar
# Processing Record 45 of Set 1 | roma
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | moba
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | coffs harbour
# Processing Record 1 of Set 2 | yelizovo
# Processing Record 2 of Set 2 | acari
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | hailey
# Processing Record 5 of Set 2 | vila franca do campo
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | benguela
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 2 | harindanga
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | vardo
# Processing Record 15 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 2 | kapaa
# Processing Record 19 of Set 2 | port hardy
# Processing Record 20 of Set 2 | padang
# Processing Record 21 of Set 2 | golspie
# Processing Record 22 of Set 2 | kaitangata
# Processing Record 23 of Set 2 | cairns
# Processing Record 24 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | lowestoft
# Processing Record 27 of Set 2 | saint anthony
# Processing Record 28 of Set 2 | batsfjord
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | grindavik
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | talara
# Processing Record 35 of Set 2 | waterford
# Processing Record 36 of Set 2 | andi
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | tanah merah
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | ardesen
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | hirara
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | san joaquin
# Processing Record 47 of Set 2 | camocim
# Processing Record 48 of Set 2 | beloha
# Processing Record 49 of Set 2 | moura
# Processing Record 50 of Set 2 | northam
# Processing Record 1 of Set 3 | moose factory
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 3 | inyonga
# Processing Record 7 of Set 3 | tanout
# Processing Record 8 of Set 3 | lasa
# Processing Record 9 of Set 3 | poum
# Processing Record 10 of Set 3 | broken hill
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | airai
# Processing Record 13 of Set 3 | eyl
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | murzzuschlag
# Processing Record 16 of Set 3 | marawi
# Processing Record 17 of Set 3 | basoko
# Processing Record 18 of Set 3 | kieta
# Processing Record 19 of Set 3 | maraba
# Processing Record 20 of Set 3 | manzanillo
# Processing Record 21 of Set 3 | clyde river
# Processing Record 22 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 23 of Set 3 | vanersborg
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | rabo de peixe
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | otjiwarongo
# Processing Record 28 of Set 3 | yulara
# Processing Record 29 of Set 3 | ahipara
# Processing Record 30 of Set 3 | bungu
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | tautira
# Processing Record 33 of Set 3 | vila velha
# Processing Record 34 of Set 3 | kahului
# Processing Record 35 of Set 3 | toamasina
# Processing Record 36 of Set 3 | omboue
# Processing Record 37 of Set 3 | taltal
# Processing Record 38 of Set 3 | geraldton
# Processing Record 39 of Set 3 | jalu
# Processing Record 40 of Set 3 | aykhal
# Processing Record 41 of Set 3 | nouadhibou
# Processing Record 42 of Set 3 | bibiani
# Processing Record 43 of Set 3 | fairbanks
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 3 | metehara
# City not found. Skipping...
# Processing Record 46 of Set 3 | zhuozhou
# City not found. Skipping...
# Processing Record 47 of Set 3 | taquaritinga do norte
# Processing Record 48 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 49 of Set 3 | buchanan
# Processing Record 50 of Set 3 | fukue
# Processing Record 1 of Set 4 | am timan
# Processing Record 2 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 4 | kasane
# Processing Record 4 of Set 4 | pano aqil
# Processing Record 5 of Set 4 | codrington
# Processing Record 6 of Set 4 | bredasdorp
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | samarai
# Processing Record 9 of Set 4 | van
# Processing Record 10 of Set 4 | cabo san lucas
# Processing Record 11 of Set 4 | pokhara
# Processing Record 12 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 4 | ahuimanu
# Processing Record 14 of Set 4 | bedele
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | shellbrook
# Processing Record 17 of Set 4 | hohhot
# Processing Record 18 of Set 4 | churapcha
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | najran
# Processing Record 25 of Set 4 | vacha
# Processing Record 26 of Set 4 | palmer
# Processing Record 27 of Set 4 | tambacounda
# Processing Record 28 of Set 4 | flinders
# Processing Record 29 of Set 4 | morbach
# Processing Record 30 of Set 4 | menongue
# Processing Record 31 of Set 4 | nakusp
# Processing Record 32 of Set 4 | porto seguro
# Processing Record 33 of Set 4 | zhangye
# Processing Record 34 of Set 4 | soe
# Processing Record 35 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | puerto colombia
# Processing Record 39 of Set 4 | ponta delgada
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | havre
# Processing Record 43 of Set 4 | ulaanbaatar
# Processing Record 44 of Set 4 | khandbari
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | bagdarin
# Processing Record 47 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 4 | beringovskiy
# Processing Record 49 of Set 4 | ulladulla
# Processing Record 50 of Set 4 | barcelos
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | dubbo
# Processing Record 4 of Set 5 | la ronge
# Processing Record 5 of Set 5 | los llanos de aridane
# Processing Record 6 of Set 5 | new norfolk
# Processing Record 7 of Set 5 | dunedin
# Processing Record 8 of Set 5 | bosaso
# Processing Record 9 of Set 5 | bluff
# Processing Record 10 of Set 5 | coolum beach
# Processing Record 11 of Set 5 | kaabong
# Processing Record 12 of Set 5 | manta
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | carnarvon
# Processing Record 15 of Set 5 | deputatskiy
# Processing Record 16 of Set 5 | nipawin
# Processing Record 17 of Set 5 | berlevag
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | rocha
# Processing Record 20 of Set 5 | sar-e pul
# Processing Record 21 of Set 5 | port-cartier
# Processing Record 22 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 5 | camacha
# Processing Record 24 of Set 5 | venado tuerto
# Processing Record 25 of Set 5 | mayya
# Processing Record 26 of Set 5 | bayir
# Processing Record 27 of Set 5 | mwene-ditu
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | puerto ayora
# Processing Record 31 of Set 5 | pangnirtung
# Processing Record 32 of Set 5 | tuy hoa
# Processing Record 33 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | oum hadjer
# Processing Record 36 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 37 of Set 5 | mahebourg
# Processing Record 38 of Set 5 | senador jose porfirio
# Processing Record 39 of Set 5 | maragogi
# Processing Record 40 of Set 5 | adeje
# Processing Record 41 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 42 of Set 5 | kalmunai
# Processing Record 43 of Set 5 | kyshtovka
# Processing Record 44 of Set 5 | ostersund
# Processing Record 45 of Set 5 | bubaque
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | mount gambier
# Processing Record 48 of Set 5 | semey
# Processing Record 49 of Set 5 | along
# Processing Record 50 of Set 5 | kuhdasht
# Processing Record 1 of Set 6 | narsaq
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | karaman
# Processing Record 4 of Set 6 | beyla
# Processing Record 5 of Set 6 | fortuna
# Processing Record 6 of Set 6 | uray
# Processing Record 7 of Set 6 | tecoanapa
# Processing Record 8 of Set 6 | piacabucu
# Processing Record 9 of Set 6 | saint-philippe
# Processing Record 10 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 11 of Set 6 | santa cruz cabralia
# Processing Record 12 of Set 6 | tromso
# Processing Record 13 of Set 6 | wajid
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | el badari
# City not found. Skipping...
# Processing Record 16 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | tasiilaq
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | seoul
# Processing Record 20 of Set 6 | khilok
# Processing Record 21 of Set 6 | alghero
# Processing Record 22 of Set 6 | iberia
# Processing Record 23 of Set 6 | kloulklubed
# Processing Record 24 of Set 6 | san nicolas
# Processing Record 25 of Set 6 | tuktoyaktuk
# Processing Record 26 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 27 of Set 6 | kavaratti
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | okakarara
# Processing Record 30 of Set 6 | makinsk
# Processing Record 31 of Set 6 | bandarbeyla
# Processing Record 32 of Set 6 | boissevain
# Processing Record 33 of Set 6 | farmington
# Processing Record 34 of Set 6 | mzimba
# Processing Record 35 of Set 6 | murmino
# Processing Record 36 of Set 6 | aranda de duero
# Processing Record 37 of Set 6 | general roca
# Processing Record 38 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 6 | aksarka
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | peniche
# Processing Record 42 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 6 | shar
# Processing Record 44 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 45 of Set 6 | norman wells
# Processing Record 46 of Set 6 | artyom
# Processing Record 47 of Set 6 | caboolture
# Processing Record 48 of Set 6 | kununurra
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | lebu
# Processing Record 1 of Set 7 | manzhouli
# Processing Record 2 of Set 7 | palanga
# Processing Record 3 of Set 7 | sirvintos
# Processing Record 4 of Set 7 | wagar
# Processing Record 5 of Set 7 | ati
# Processing Record 6 of Set 7 | heidelberg
# Processing Record 7 of Set 7 | mashhad
# Processing Record 8 of Set 7 | kutum
# Processing Record 9 of Set 7 | buin
# Processing Record 10 of Set 7 | ginir
# Processing Record 11 of Set 7 | salyan
# Processing Record 12 of Set 7 | gayny
# Processing Record 13 of Set 7 | dikson
# Processing Record 14 of Set 7 | ixtapa
# Processing Record 15 of Set 7 | tilichiki
# Processing Record 16 of Set 7 | guerrero negro
# Processing Record 17 of Set 7 | milkovo
# Processing Record 18 of Set 7 | makakilo city
# Processing Record 19 of Set 7 | biak
# Processing Record 20 of Set 7 | namibe
# Processing Record 21 of Set 7 | atar
# Processing Record 22 of Set 7 | liverpool
# Processing Record 23 of Set 7 | buala
# Processing Record 24 of Set 7 | kupang
# Processing Record 25 of Set 7 | salinopolis
# Processing Record 26 of Set 7 | mogadishu
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | varzea da palma
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | libertador general san martin
# Processing Record 31 of Set 7 | senneterre
# Processing Record 32 of Set 7 | sobolevo
# Processing Record 33 of Set 7 | urusha
# Processing Record 34 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 7 | paragominas
# Processing Record 36 of Set 7 | tomatlan
# Processing Record 37 of Set 7 | sakaiminato
# Processing Record 38 of Set 7 | diffa
# Processing Record 39 of Set 7 | ishlei
# City not found. Skipping...
# Processing Record 40 of Set 7 | kortkeros
# Processing Record 41 of Set 7 | junin
# Processing Record 42 of Set 7 | jumla
# Processing Record 43 of Set 7 | simao
# Processing Record 44 of Set 7 | san quintin
# Processing Record 45 of Set 7 | paamiut
# Processing Record 46 of Set 7 | maningrida
# Processing Record 47 of Set 7 | koungou
# Processing Record 48 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 49 of Set 7 | iwanai
# Processing Record 50 of Set 7 | aklavik
# Processing Record 1 of Set 8 | isiro
# Processing Record 2 of Set 8 | hualmay
# Processing Record 3 of Set 8 | bengkulu
# Processing Record 4 of Set 8 | santa marta
# Processing Record 5 of Set 8 | vakhrushi
# Processing Record 6 of Set 8 | claveria
# Processing Record 7 of Set 8 | kodinsk
# Processing Record 8 of Set 8 | esmeraldas
# Processing Record 9 of Set 8 | baherden
# Processing Record 10 of Set 8 | skjervoy
# Processing Record 11 of Set 8 | itamarandiba
# Processing Record 12 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 8 | destin
# Processing Record 14 of Set 8 | kurilsk
# Processing Record 15 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 8 | malanville
# Processing Record 17 of Set 8 | nuuk
# Processing Record 18 of Set 8 | trairi
# Processing Record 19 of Set 8 | port lincoln
# Processing Record 20 of Set 8 | tres picos
# Processing Record 21 of Set 8 | xining
# Processing Record 22 of Set 8 | mtambile
# Processing Record 23 of Set 8 | sal rei
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | umm lajj
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | harstad
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | ivanishchi
# Processing Record 30 of Set 8 | asfi
# Processing Record 31 of Set 8 | ciudad bolivar
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | aktau
# Processing Record 34 of Set 8 | kamenka
# Processing Record 35 of Set 8 | victoria
# Processing Record 36 of Set 8 | lorengau
# Processing Record 37 of Set 8 | touros
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | ejura
# Processing Record 40 of Set 8 | sistranda
# Processing Record 41 of Set 8 | lazaro cardenas
# Processing Record 42 of Set 8 | sabzevar
# Processing Record 43 of Set 8 | syracuse
# Processing Record 44 of Set 8 | saint-pierre
# Processing Record 45 of Set 8 | cartagena
# Processing Record 46 of Set 8 | dickinson
# Processing Record 47 of Set 8 | mayo
# Processing Record 48 of Set 8 | kota tinggi
# Processing Record 49 of Set 8 | sept-iles
# Processing Record 50 of Set 8 | akyab
# Processing Record 1 of Set 9 | kainantu
# Processing Record 2 of Set 9 | tolaga bay
# Processing Record 3 of Set 9 | kavieng
# Processing Record 4 of Set 9 | sao raimundo das mangabeiras
# Processing Record 5 of Set 9 | ayan
# Processing Record 6 of Set 9 | bellevue
# Processing Record 7 of Set 9 | marquette
# Processing Record 8 of Set 9 | szirmabesenyo
# Processing Record 9 of Set 9 | rognan
# Processing Record 10 of Set 9 | pedro juan caballero
# Processing Record 11 of Set 9 | constitucion
# Processing Record 12 of Set 9 | chateaubelair
# Processing Record 13 of Set 9 | preobrazheniye
# Processing Record 14 of Set 9 | altamira
# Processing Record 15 of Set 9 | pasrur
# Processing Record 16 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 9 | cananeia
# Processing Record 18 of Set 9 | chipata
# Processing Record 19 of Set 9 | murgab
# Processing Record 20 of Set 9 | vila do maio
# Processing Record 21 of Set 9 | ternate
# Processing Record 22 of Set 9 | sao joao da barra
# Processing Record 23 of Set 9 | port hawkesbury
# Processing Record 24 of Set 9 | lampazos de naranjo
# Processing Record 25 of Set 9 | marsa matruh
# Processing Record 26 of Set 9 | san rafael
# Processing Record 27 of Set 9 | dicabisagan
# Processing Record 28 of Set 9 | lewisporte
# Processing Record 29 of Set 9 | naze
# Processing Record 30 of Set 9 | rochester
# Processing Record 31 of Set 9 | buta
# Processing Record 32 of Set 9 | zhanaozen
# Processing Record 33 of Set 9 | tonantins
# Processing Record 34 of Set 9 | bilma
# Processing Record 35 of Set 9 | ketchikan
# Processing Record 36 of Set 9 | aldama
# Processing Record 37 of Set 9 | itarema
# Processing Record 38 of Set 9 | auki
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | sanjwal
# Processing Record 41 of Set 9 | windhoek
# Processing Record 42 of Set 9 | gizo
# Processing Record 43 of Set 9 | hovd
# Processing Record 44 of Set 9 | izhma
# Processing Record 45 of Set 9 | bingol
# Processing Record 46 of Set 9 | faya
# Processing Record 47 of Set 9 | laredo
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 9 | port alberni
# Processing Record 1 of Set 10 | arawa
# Processing Record 2 of Set 10 | cozumel
# Processing Record 3 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 4 of Set 10 | anadyr
# Processing Record 5 of Set 10 | taiobeiras
# Processing Record 6 of Set 10 | belinskiy
# Processing Record 7 of Set 10 | minab
# Processing Record 8 of Set 10 | leningradskiy
# Processing Record 9 of Set 10 | srednekolymsk
# Processing Record 10 of Set 10 | tabou
# Processing Record 11 of Set 10 | ukiah
# Processing Record 12 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 13 of Set 10 | bridlington
# Processing Record 14 of Set 10 | bagotville
# Processing Record 15 of Set 10 | nong phai
# Processing Record 16 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 10 | bull savanna
# Processing Record 18 of Set 10 | qasigiannguit
# Processing Record 19 of Set 10 | bambanglipuro
# Processing Record 20 of Set 10 | esperance
# Processing Record 21 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 10 | iquique
# Processing Record 24 of Set 10 | crotone
# Processing Record 25 of Set 10 | riyadh
# Processing Record 26 of Set 10 | japura
# Processing Record 27 of Set 10 | balabac
# Processing Record 28 of Set 10 | soyo
# Processing Record 29 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 10 | evensk
# Processing Record 31 of Set 10 | pochutla
# Processing Record 32 of Set 10 | venice
# Processing Record 33 of Set 10 | fare
# Processing Record 34 of Set 10 | basco
# Processing Record 35 of Set 10 | ola
# Processing Record 36 of Set 10 | ye
# City not found. Skipping...
# Processing Record 37 of Set 10 | bonthe
# Processing Record 38 of Set 10 | paonta sahib
# Processing Record 39 of Set 10 | xinqing
# Processing Record 40 of Set 10 | san vicente
# Processing Record 41 of Set 10 | kaniama
# Processing Record 42 of Set 10 | chapayevka
# Processing Record 43 of Set 10 | bumba
# Processing Record 44 of Set 10 | lokosovo
# Processing Record 45 of Set 10 | marzuq
# Processing Record 46 of Set 10 | bilibino
# Processing Record 47 of Set 10 | brae
# Processing Record 48 of Set 10 | grand gaube
# Processing Record 49 of Set 10 | ponta do sol
# Processing Record 50 of Set 10 | harper
# Processing Record 1 of Set 11 | hokitika
# Processing Record 2 of Set 11 | ust-maya
# Processing Record 3 of Set 11 | pyshma
# Processing Record 4 of Set 11 | pringsewu
# Processing Record 5 of Set 11 | kruisfontein
# Processing Record 6 of Set 11 | puerto baquerizo moreno
# Processing Record 7 of Set 11 | tarakan
# Processing Record 8 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 9 of Set 11 | cerignola
# Processing Record 10 of Set 11 | klaksvik
# Processing Record 11 of Set 11 | labytnangi
# Processing Record 12 of Set 11 | oyama
# Processing Record 13 of Set 11 | sorong
# Processing Record 14 of Set 11 | yarada
# Processing Record 15 of Set 11 | maridi
# Processing Record 16 of Set 11 | horsham
# Processing Record 17 of Set 11 | chengde
# Processing Record 18 of Set 11 | luderitz
# Processing Record 19 of Set 11 | henties bay
# Processing Record 20 of Set 11 | musoma
# Processing Record 21 of Set 11 | lakatoro
# Processing Record 22 of Set 11 | rio gallegos
# Processing Record 23 of Set 11 | ningbo
# Processing Record 24 of Set 11 | nemuro
# Processing Record 25 of Set 11 | san ignacio
# Processing Record 26 of Set 11 | palmeira
# Processing Record 27 of Set 11 | zaraza
# Processing Record 28 of Set 11 | clevelandia
# Processing Record 29 of Set 11 | salalah
# Processing Record 30 of Set 11 | muros
# Processing Record 31 of Set 11 | brigantine
# Processing Record 32 of Set 11 | glenluce
# Processing Record 33 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 34 of Set 11 | alice springs
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | atasu
# Processing Record 37 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 11 | nacala
# Processing Record 39 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 11 | hambantota
# Processing Record 41 of Set 11 | sambava
# Processing Record 42 of Set 11 | rantepao
# Processing Record 43 of Set 11 | santiago del estero
# Processing Record 44 of Set 11 | santa barbara
# Processing Record 45 of Set 11 | madingou
# Processing Record 46 of Set 11 | tinaquillo
# Processing Record 47 of Set 11 | namatanai
# Processing Record 48 of Set 11 | monywa
# Processing Record 49 of Set 11 | qaqortoq
# Processing Record 50 of Set 11 | mnogovershinnyy
# Processing Record 1 of Set 12 | karratha
# Processing Record 2 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 12 | jerome
# Processing Record 4 of Set 12 | bijar
# Processing Record 5 of Set 12 | lambarene
# Processing Record 6 of Set 12 | magadan
# Processing Record 7 of Set 12 | avera
# Processing Record 8 of Set 12 | ronne
# Processing Record 9 of Set 12 | wajima
# Processing Record 10 of Set 12 | seydi
# Processing Record 11 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 12 | rawson
# Processing Record 13 of Set 12 | morki
# Processing Record 14 of Set 12 | pekalongan
# Processing Record 15 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 12 | tiznit
# Processing Record 17 of Set 12 | chapais
# Processing Record 18 of Set 12 | bud
# Processing Record 19 of Set 12 | mahon
# Processing Record 20 of Set 12 | tutoia
# Processing Record 21 of Set 12 | san jose
# Processing Record 22 of Set 12 | terme
# Processing Record 23 of Set 12 | ouadda
# Processing Record 24 of Set 12 | saldanha
# Processing Record 25 of Set 12 | alta floresta
# Processing Record 26 of Set 12 | bitkine
# Processing Record 27 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 12 | hervey bay
# Processing Record 29 of Set 12 | carballo
# Processing Record 30 of Set 12 | qorveh
# Processing Record 31 of Set 12 | bistret
# Processing Record 32 of Set 12 | nome
# Processing Record 33 of Set 12 | vanimo
# Processing Record 34 of Set 12 | tiffin
# Processing Record 35 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 36 of Set 12 | vostok
# Processing Record 37 of Set 12 | sao felix do xingu
# Processing Record 38 of Set 12 | briceno
# Processing Record 39 of Set 12 | nha trang
# Processing Record 40 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 12 | carmen
# Processing Record 42 of Set 12 | hay river
# Processing Record 43 of Set 12 | el jicaro
# Processing Record 44 of Set 12 | fethiye
# Processing Record 45 of Set 12 | hue
# Processing Record 46 of Set 12 | the valley
# Processing Record 47 of Set 12 | saint-joseph
# Processing Record 48 of Set 12 | lubango
# Processing Record 49 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 12 | bogorodskoye
# Processing Record 1 of Set 13 | olafsvik
# Processing Record 2 of Set 13 | santa cruz del sur
# Processing Record 3 of Set 13 | laranjeiras do sul
# Processing Record 4 of Set 13 | lagoa
# Processing Record 5 of Set 13 | shestakovo
# Processing Record 6 of Set 13 | vicuna
# Processing Record 7 of Set 13 | balikpapan
# Processing Record 8 of Set 13 | contai
# Processing Record 9 of Set 13 | port elizabeth
# Processing Record 10 of Set 13 | melendugno
# Processing Record 11 of Set 13 | puerto ayacucho
# Processing Record 12 of Set 13 | cassilandia
# Processing Record 13 of Set 13 | kautokeino
# Processing Record 14 of Set 13 | pithoragarh
# Processing Record 15 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 13 | biggar
# Processing Record 17 of Set 13 | darnah
# Processing Record 18 of Set 13 | buraydah
# Processing Record 19 of Set 13 | nara
# Processing Record 20 of Set 13 | kungsbacka
# Processing Record 21 of Set 13 | havre-saint-pierre
# Processing Record 22 of Set 13 | ossora
# Processing Record 23 of Set 13 | bandar-e anzali
# Processing Record 24 of Set 13 | taree
# Processing Record 25 of Set 13 | caconda
# Processing Record 26 of Set 13 | candawaga
# City not found. Skipping...
# Processing Record 27 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 28 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 29 of Set 13 | nyurba
# Processing Record 30 of Set 13 | boddam
# Processing Record 31 of Set 13 | chinsali
# Processing Record 32 of Set 13 | hami
# Processing Record 33 of Set 13 | katrineholm
# Processing Record 34 of Set 13 | gazimurskiy zavod
# Processing Record 35 of Set 13 | baruun-urt
# Processing Record 36 of Set 13 | gornopravdinsk
# Processing Record 37 of Set 13 | bereda
# Processing Record 38 of Set 13 | visby
# Processing Record 39 of Set 13 | chumikan
# Processing Record 40 of Set 13 | koumac
# Processing Record 41 of Set 13 | barra do garcas
# Processing Record 42 of Set 13 | nyagan
# Processing Record 43 of Set 13 | san cristobal
# Processing Record 44 of Set 13 | digby
# Processing Record 45 of Set 13 | tres arroyos
# Processing Record 46 of Set 13 | myitkyina
# Processing Record 47 of Set 13 | liminangcong
# City not found. Skipping...
# Processing Record 48 of Set 13 | kitimat
# Processing Record 49 of Set 13 | qandala
# Processing Record 50 of Set 13 | washougal
# Processing Record 1 of Set 14 | tairua
# Processing Record 2 of Set 14 | ilo
# Processing Record 3 of Set 14 | ipanema
# Processing Record 4 of Set 14 | patiya
# Processing Record 5 of Set 14 | kuching
# Processing Record 6 of Set 14 | shumskiy
# Processing Record 7 of Set 14 | rio grande
# Processing Record 8 of Set 14 | katakwi
# Processing Record 9 of Set 14 | rodrigues alves
# Processing Record 10 of Set 14 | bahia honda
# Processing Record 11 of Set 14 | inegol
# Processing Record 12 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 13 of Set 14 | concepcion del oro
# Processing Record 14 of Set 14 | chifeng
# Processing Record 15 of Set 14 | krasnoselkup
# Processing Record 16 of Set 14 | roberval
# Processing Record 17 of Set 14 | constanza
# Processing Record 18 of Set 14 | platteville
# Processing Record 19 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 14 | zigong
# Processing Record 21 of Set 14 | miguel hidalgo
# Processing Record 22 of Set 14 | kysyl-syr
# Processing Record 23 of Set 14 | road town
# Processing Record 24 of Set 14 | sindor
# Processing Record 25 of Set 14 | safaga
# Processing Record 26 of Set 14 | camalu
# Processing Record 27 of Set 14 | adrar
# Processing Record 28 of Set 14 | puerto maldonado
# Processing Record 29 of Set 14 | porto novo
# Processing Record 30 of Set 14 | borgo san lorenzo
# Processing Record 31 of Set 14 | coos bay
# Processing Record 32 of Set 14 | cascais
# Processing Record 33 of Set 14 | tucuman
# Processing Record 34 of Set 14 | yerbogachen
# Processing Record 35 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 36 of Set 14 | lukovetskiy
# Processing Record 37 of Set 14 | pitimbu
# Processing Record 38 of Set 14 | olinda
# Processing Record 39 of Set 14 | mecca
# Processing Record 40 of Set 14 | waddan
# Processing Record 41 of Set 14 | baboua
# City not found. Skipping...
# Processing Record 42 of Set 14 | nantucket
# Processing Record 43 of Set 14 | swan hill
# Processing Record 44 of Set 14 | krasnovishersk
# Processing Record 45 of Set 14 | cruz alta
# Processing Record 46 of Set 14 | yinchuan
# Processing Record 47 of Set 14 | luena
# Processing Record 48 of Set 14 | mishan
# Processing Record 49 of Set 14 | yanam
# Processing Record 50 of Set 14 | muzhi
# Processing Record 1 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 2 of Set 15 | sola
# Processing Record 3 of Set 15 | itaituba
# Processing Record 4 of Set 15 | kynsperk nad ohri
# Processing Record 5 of Set 15 | matara
# Processing Record 6 of Set 15 | naron
# Processing Record 7 of Set 15 | salisbury
# Processing Record 8 of Set 15 | caruray
# Processing Record 9 of Set 15 | markova
# Processing Record 10 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 15 | bathsheba
# Processing Record 12 of Set 15 | opunake
# Processing Record 13 of Set 15 | sawakin
# Processing Record 14 of Set 15 | centralina
# Processing Record 15 of Set 15 | zhezkazgan
# Processing Record 16 of Set 15 | thunder bay
# Processing Record 17 of Set 15 | minna
# Processing Record 18 of Set 15 | tondano
# Processing Record 19 of Set 15 | turukhansk
# Processing Record 20 of Set 15 | columbus
# Processing Record 21 of Set 15 | aborlan
# Processing Record 22 of Set 15 | lat yao
# Processing Record 23 of Set 15 | lithakia
# Processing Record 24 of Set 15 | solnechnyy
# Processing Record 25 of Set 15 | stokmarknes
# Processing Record 26 of Set 15 | milas
# Processing Record 27 of Set 15 | changping
# Processing Record 28 of Set 15 | rundu
# Processing Record 29 of Set 15 | banjar
# Processing Record 30 of Set 15 | weinan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0       Santa Cruz -17.8000  -63.1667     78.85       broken clouds        44
# 1        Jamestown  42.0970  -79.2353     65.84          light rain        94
# 2         Baturite  -4.3286  -38.8847     83.70    scattered clouds        64
# 3        Riihimaki  60.7377   24.7773     53.94     overcast clouds        37
# 4             Boda   4.3189   17.4695     81.81    scattered clouds        56
# 5     Punta Arenas -53.1500  -70.9167     39.31    scattered clouds        70
# 6   Severo-Kurilsk  50.6789  156.1250     40.35     overcast clouds        96
# 7           Dingle  10.9995  122.6711     77.61     overcast clouds        90
# 8           Albany  42.6001  -73.9662     88.92    scattered clouds        50
# 9  Bambous Virieux -20.3428   57.7575     75.45          light rain        73
#
#    Cloudiness  Wind Speed Country
# 0          75        9.22      BO
# 1         100       11.50      US
# 2          41        8.70      BR
# 3          89        5.10      FI
# 4          49        3.40      CF
# 5          40       16.11      CL
# 6         100       16.22      RU
# 7         100        4.25      PH
# 8          35       10.04      US
# 9          40       10.36      MU

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Santa Cruz      BO -17.8000  -63.1667     78.85        44          75
# 1        Jamestown      US  42.0970  -79.2353     65.84        94         100
# 2         Baturite      BR  -4.3286  -38.8847     83.70        64          41
# 3        Riihimaki      FI  60.7377   24.7773     53.94        37          89
# 4             Boda      CF   4.3189   17.4695     81.81        56          49
# 5     Punta Arenas      CL -53.1500  -70.9167     39.31        70          40
# 6   Severo-Kurilsk      RU  50.6789  156.1250     40.35        96         100
# 7           Dingle      PH  10.9995  122.6711     77.61        90         100
# 8           Albany      US  42.6001  -73.9662     88.92        50          35
# 9  Bambous Virieux      MU -20.3428   57.7575     75.45        73          40
#
#    Wind Speed Current Description
# 0        9.22       broken clouds
# 1       11.50          light rain
# 2        8.70    scattered clouds
# 3        5.10     overcast clouds
# 4        3.40    scattered clouds
# 5       16.11    scattered clouds
# 6       16.22     overcast clouds
# 7        4.25     overcast clouds
# 8       10.04    scattered clouds
# 9       10.36          light rain

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
